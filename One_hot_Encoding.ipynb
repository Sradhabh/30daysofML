# %% [markdown]
# <a href="https://colab.research.google.com/github/Sradhabh/30daysofML/blob/main/One_hot_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6598dc00-a8d8-48c5-9c1d-9590d86a2a4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6598dc00-a8d8-48c5-9c1d-9590d86a2a4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
file_name = 'bengaluru_house_prices.csv'
df = pd.read_csv(file_name)

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
dummies = pd.get_dummies(df.area_type)
dummies
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0                   0             0           0                     1
# 1                   0             0           1                     0
# 2                   1             0           0                     0
# 3                   0             0           0                     1
# 4                   0             0           0                     1
# ...               ...           ...         ...                   ...
# 13315               1             0           0                     0
# 13316               0             0           0                     1
# 13317               1             0           0                     0
# 13318               0             0           0                     1
# 13319               0             0           0                     1
#
# [13320 rows x 4 columns]

# %%
merged = pd.concat([df,dummies], axis = 'columns')
merged.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'Built-up  Area',
#        'Carpet  Area', 'Plot  Area', 'Super built-up  Area'],
#       dtype='object')

# %%
d2 = merged.drop('Super built-up  Area', axis = 'columns')

d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   area_type       13320 non-null  object
#  1   availability    13320 non-null  object
#  2   location        13319 non-null  object
#  3   size            13304 non-null  object
#  4   society         7818 non-null   object
#  5   total_sqft      13320 non-null  object
#  6   bath            13247 non-null  float64
#  7   balcony         12711 non-null  float64
#  8   price           13320 non-null  float64
#  9   Built-up  Area  13320 non-null  uint8
#  10  Carpet  Area    13320 non-null  uint8
#  11  Plot  Area      13320 non-null  uint8
# dtypes: float64(3), object(6), uint8(3)
# memory usage: 975.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.area_type = le.fit_transform(dfle.area_type)
dfle
# Out:
#        area_type   availability                  location       size  society  \
# 0              3         19-Dec  Electronic City Phase II      2 BHK  Coomee
# 1              2  Ready To Move          Chikka Tirupathi  4 Bedroom  Theanmp
# 2              0  Ready To Move               Uttarahalli      3 BHK      NaN
# 3              3  Ready To Move        Lingadheeranahalli      3 BHK  Soiewre
# 4              3  Ready To Move                  Kothanur      2 BHK      NaN
# ...          ...            ...                       ...        ...      ...
# 13315          0  Ready To Move                Whitefield  5 Bedroom  ArsiaEx
# 13316          3  Ready To Move             Richards Town      4 BHK      NaN
# 13317          0  Ready To Move     Raja Rajeshwari Nagar      2 BHK  Mahla T
# 13318          3         18-Jun           Padmanabhanagar      4 BHK  SollyCl
# 13319          3  Ready To Move              Doddathoguru      1 BHK      NaN
#
# ...
